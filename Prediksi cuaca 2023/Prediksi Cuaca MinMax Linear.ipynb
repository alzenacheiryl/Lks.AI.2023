# %% [markdown]
# # Prediksi Cuaca

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Import library

# %%
#Import library yang dibutuhkan 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Menampilkan data

# %%
#Membaca datafile kita dan mengambil beberapa kolom yg dibutuhkan saja
df = pd.read_csv('train_dataset.csv')

# %%
df.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          30.3          21.1    61.741207    87.262192         26.629430
# 1          29.3          20.9    85.943954    97.694801         25.380395
# 2          29.5          22.2    32.008099    69.966370         31.991670
# 3          32.6          21.2    60.070614    91.244827         27.043616
# 4          33.0          27.6    62.508846    86.983963         31.529577
#
#    LDAPS_Tmin_lapse   LDAPS_WS   LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.075077   4.263528  21.399026   0.297776   0.616711  ...
# 1         23.275475   8.697955  53.165713   0.901123   0.867350  ...
# 2         21.475995  10.461500  37.582673   0.012838   0.086090  ...
# 3         23.338373  15.686361  95.842065   0.622580   0.388476  ...
# 4         27.307177   6.493082  49.887497   0.438076   0.458994  ...
#
#    LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0    0.000000    0.000000    0.000479    0.000000  37.5776  126.938   75.0924
# 1    2.642577    0.261794    0.288428    2.315489  37.5507  126.988  132.1180
# 2    0.000000    0.000000    0.000000    0.000000  37.5507  126.937   30.0464
# 3    0.285723    0.335796    0.000000    0.000000  37.6046  127.032   44.7624
# 4    0.000000    0.000000    0.000000    0.000000  37.5102  127.042   54.6384
#
#     Slope  Solar radiation  Next_Tmax
# 0  1.7678      5131.667480       26.4
# 1  0.5931      5918.901367       25.6
# 2  0.8552      5222.419434       30.6
# 3  0.5141      5558.630371       27.2
# 4  0.1457      5635.460449       32.8
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 6584          31.4          25.9    70.250511    90.605248         29.778636
# 6585          32.8          20.3    42.189671    69.954666         28.652535
# 6586          31.0          24.7    52.810146    86.206841         32.837630
# 6587          27.0          24.0    73.445656    93.612633         27.240955
# 6588          28.8          23.0    37.213074    94.007675         32.002693
#
#       LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 6584         25.518494   7.424166   35.116337   0.569784   0.772786  ...
# 6585         20.329686  12.924104  141.607279   0.116489   0.137232  ...
# 6586         25.710858   6.580249   97.316694   0.025348   0.100569  ...
# 6587         24.875103   5.304328   29.945006   0.576503   0.678209  ...
# 6588         23.374335   5.745168   56.699324   0.221865   0.116836  ...
#
#       LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon  \
# 6584    0.037094    1.200366         0.0         0.0  37.5776  127.083
# 6585    0.000000    0.000000         0.0         0.0  37.4697  126.995
# 6586    0.000000    0.000000         0.0         0.0  37.4697  126.995
# 6587    0.119012    0.565905         0.0         0.0  37.5372  127.085
# 6588    0.000000    0.000000         0.0         0.0  37.6046  127.032
#
#           DEM   Slope  Solar radiation  Next_Tmax
# 6584  59.8324  2.6865      5310.041992       33.8
# 6585  82.2912  2.2579      5712.382324       27.4
# 6586  82.2912  2.2579      5241.705566       33.0
# 6587  28.7000  0.6233      5694.289551       27.0
# 6588  44.7624  0.5141      4731.177734       32.3
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Menampilkan informasi data

# %%
df.shape
# Out:
# (6589, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6589 entries, 0 to 6588
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Present_Tmax      6528 non-null   float64
#  1   Present_Tmin      6528 non-null   float64
#  2   LDAPS_RHmin       6524 non-null   float64
#  3   LDAPS_RHmax       6524 non-null   float64
#  4   LDAPS_Tmax_lapse  6524 non-null   float64
#  5   LDAPS_Tmin_lapse  6524 non-null   float64
#  6   LDAPS_WS          6524 non-null   float64
#  7   LDAPS_LH          6524 non-null   float64
#  8   LDAPS_CC1         6524 non-null   float64
#  9   LDAPS_CC2         6524 non-null   float64
#  10  LDAPS_CC3         6524 non-null   float64
#  11  LDAPS_CC4         6524 non-null   float64
#  12  LDAPS_PPT1        6524 non-null   float64
#  13  LDAPS_PPT2        6524 non-null   float64
#  14  LDAPS_PPT3        6524 non-null   float64
#  15  LDAPS_PPT4        6524 non-null   float64
#  16  lat               6589 non-null   float64
#  17  lon               6589 non-null   float64
#  18  DEM               6589 non-null   float64
#  19  Slope             6589 non-null   float64
#  20  Solar radiation   6589 non-null   float64
#  21  Next_Tmax         6567 non-null   float64
# dtypes: float64(22)
# memory usage: 1.1 MB

# %% [markdown]
# Arti dari setiap variabel :
# 1. T Temperature present- suhu saat ini
# 2. RH Relative Humidity - keleembapan relatif
# 3. T Temperature lapse - selang suhu
# 4. WS
# 5. LH
# 6. CC CLOUD COVER - 1: clear sky>cerah, 2: scattered clouds>sebaran awan, 3: broken clouds>awan pecah, 4:overcast>mendung
# 7. PPT
# 8. lat latitude
# 9. lon longitude
# 10. DEM
# 11. lereng
# 12. radiasi matahari
# 13. suhu berikutnya

# %%
df.describe()
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   6528.000000   6528.000000  6524.000000  6524.000000       6524.000000
# mean      29.767203     23.217862    56.733485    88.375947         29.618749
# std        2.983094      2.429038    14.643501     7.201419          2.949113
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.600000    45.957097    84.224436         27.662062
# 50%       29.900000     23.400000    55.017689    89.798084         29.697722
# 75%       32.000000     24.900000    67.205536    93.771591         31.729855
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       6524.000000  6524.000000  6524.000000  6524.000000  6524.000000
# mean          23.514294     7.078863    62.607915     0.368274     0.356035
# std            2.345499     2.151549    33.846639     0.263172     0.258348
# min           14.272646     2.882580   -13.603212     0.000000     0.000000
# 25%           22.100277     5.681878    37.253107     0.145684     0.138993
# 50%           23.763636     6.540526    56.871052     0.314975     0.313254
# 75%           25.147837     7.990957    84.235666     0.574132     0.557710
# max           29.619342    21.857621   213.414006     0.967277     0.968353
#
#        ...   LDAPS_PPT1   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  ...  6524.000000  6524.000000  6524.000000  6524.000000  6589.000000
# mean   ...     0.578082     0.479413     0.280178     0.273615    37.544970
# std    ...     1.919926     1.745113     1.169598     1.230588     0.050402
# min    ...     0.000000     0.000000     0.000000     0.000000    37.456200
# 25%    ...     0.000000     0.000000     0.000000     0.000000    37.510200
# 50%    ...     0.000000     0.000000     0.000000     0.000000    37.550700
# 75%    ...     0.049101     0.016580     0.007753     0.000000    37.577600
# max    ...    23.701544    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax
# count  6589.000000  6589.000000  6589.000000      6589.000000  6567.000000
# mean    126.991331    62.042712     1.254981      5342.443957    30.284102
# std       0.079562    54.485681     1.368080       429.247389     3.132548
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      5004.824219    28.200000
# 50%     126.995000    45.716000     0.618000      5435.520020    30.500000
# 75%     127.042000    59.832400     1.767800      5730.027832    32.700000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Categorical

# %%
# Melihat data kategorikal

categorical = [var for var in df.columns if df[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :', categorical)
df[categorical].head()
# Out:
# There are 0 categorical variables
#
# The categorical variables are : []
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# ### Numerical

# %%
# find numerical variables
numerical = [var for var in df.columns if df[var].dtype!='O']
print('There are {} numerical variables\n'.format(len(numerical)))
print('The numerical variables are :', numerical)
df[numerical].head()
# Out:
# There are 22 numerical variables
#
# The numerical variables are : ['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope', 'Solar radiation', 'Next_Tmax']
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          30.3          21.1    61.741207    87.262192         26.629430
# 1          29.3          20.9    85.943954    97.694801         25.380395
# 2          29.5          22.2    32.008099    69.966370         31.991670
# 3          32.6          21.2    60.070614    91.244827         27.043616
# 4          33.0          27.6    62.508846    86.983963         31.529577
#
#    LDAPS_Tmin_lapse   LDAPS_WS   LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.075077   4.263528  21.399026   0.297776   0.616711  ...
# 1         23.275475   8.697955  53.165713   0.901123   0.867350  ...
# 2         21.475995  10.461500  37.582673   0.012838   0.086090  ...
# 3         23.338373  15.686361  95.842065   0.622580   0.388476  ...
# 4         27.307177   6.493082  49.887497   0.438076   0.458994  ...
#
#    LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0    0.000000    0.000000    0.000479    0.000000  37.5776  126.938   75.0924
# 1    2.642577    0.261794    0.288428    2.315489  37.5507  126.988  132.1180
# 2    0.000000    0.000000    0.000000    0.000000  37.5507  126.937   30.0464
# 3    0.285723    0.335796    0.000000    0.000000  37.6046  127.032   44.7624
# 4    0.000000    0.000000    0.000000    0.000000  37.5102  127.042   54.6384
#
#     Slope  Solar radiation  Next_Tmax
# 0  1.7678      5131.667480       26.4
# 1  0.5931      5918.901367       25.6
# 2  0.8552      5222.419434       30.6
# 3  0.5141      5558.630371       27.2
# 4  0.1457      5635.460449       32.8
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Unique values

# %%
unique_values = df.nunique()
unique_values
# Out:
# Present_Tmax         167
# Present_Tmin         153
# LDAPS_RHmin         6520
# LDAPS_RHmax         6513
# LDAPS_Tmax_lapse    6522
# LDAPS_Tmin_lapse    6523
# LDAPS_WS            6523
# LDAPS_LH            6523
# LDAPS_CC1           6430
# LDAPS_CC2           6442
# LDAPS_CC3           6456
# LDAPS_CC4           6398
# LDAPS_PPT1          2368
# LDAPS_PPT2          2129
# LDAPS_PPT3          1988
# LDAPS_PPT4          1619
# lat                   12
# lon                   25
# DEM                   25
# Slope                 27
# Solar radiation     1571
# Next_Tmax            180
# dtype: int64

# %%
#Visualisasi Unique Values
fig = plt.figure(figsize=(35,10))
plt.bar(df.columns, unique_values)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
addlabels(df.columns, unique_values)

fig.suptitle('Visualisasi Unique Values dari Dataset', fontsize=20)
plt.xlabel('Variabel', fontsize=10)
# Out:
# Text(0.5, 0, 'Variabel')

# %% [markdown]
# ### Missing value

# %%
missing_value = df.isnull().sum()
missing_value
# Out:
# Present_Tmax        61
# Present_Tmin        61
# LDAPS_RHmin         65
# LDAPS_RHmax         65
# LDAPS_Tmax_lapse    65
# LDAPS_Tmin_lapse    65
# LDAPS_WS            65
# LDAPS_LH            65
# LDAPS_CC1           65
# LDAPS_CC2           65
# LDAPS_CC3           65
# LDAPS_CC4           65
# LDAPS_PPT1          65
# LDAPS_PPT2          65
# LDAPS_PPT3          65
# LDAPS_PPT4          65
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           22
# dtype: int64

# %%
#Visualisasi Unique Values
fig = plt.figure(figsize=(35,10))
plt.bar(df.columns, missing_value)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
addlabels(df.columns, missing_value)

fig.suptitle('Visualisasi Unique Values dari Dataset', fontsize=20)
plt.xlabel('Variabel', fontsize=10)
# Out:
# Text(0.5, 0, 'Variabel')

# %% [markdown]
# ### Outliers

# %%
#Menampilkan histogram data 
df.hist(bins=10, figsize=(20,20))

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6589 entries, 0 to 6588
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Present_Tmax      6528 non-null   float64
#  1   Present_Tmin      6528 non-null   float64
#  2   LDAPS_RHmin       6524 non-null   float64
#  3   LDAPS_RHmax       6524 non-null   float64
#  4   LDAPS_Tmax_lapse  6524 non-null   float64
#  5   LDAPS_Tmin_lapse  6524 non-null   float64
#  6   LDAPS_WS          6524 non-null   float64
#  7   LDAPS_LH          6524 non-null   float64
#  8   LDAPS_CC1         6524 non-null   float64
#  9   LDAPS_CC2         6524 non-null   float64
#  10  LDAPS_CC3         6524 non-null   float64
#  11  LDAPS_CC4         6524 non-null   float64
#  12  LDAPS_PPT1        6524 non-null   float64
#  13  LDAPS_PPT2        6524 non-null   float64
#  14  LDAPS_PPT3        6524 non-null   float64
#  15  LDAPS_PPT4        6524 non-null   float64
#  16  lat               6589 non-null   float64
#  17  lon               6589 non-null   float64
#  18  DEM               6589 non-null   float64
#  19  Slope             6589 non-null   float64
#  20  Solar radiation   6589 non-null   float64
#  21  Next_Tmax         6567 non-null   float64
# dtypes: float64(22)
# memory usage: 1.1 MB

# %%
#Menampilkan outliers dalam bentuk grafik
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='Solar radiation')
fig.set_title('')
fig.set_ylabel('Solar radiation')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Next_Tmax')
fig.set_title('')
fig.set_ylabel('Next_Tmax')
# Out:
# Text(0, 0.5, 'Next_Tmax')

# %%
#Menampilkan outliers dalam bentuk grafik
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='LDAPS_CC1')
fig.set_title('')
fig.set_ylabel('LDAPS_CC1')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='LDAPS_CC2')
fig.set_title('')
fig.set_ylabel('LDAPS_CC2')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='LDAPS_CC3')
fig.set_title('')
fig.set_ylabel('LDAPS_CC3')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='LDAPS_CC4')
fig.set_title('')
fig.set_ylabel('LDAPS_CC4')
# Out:
# Text(0, 0.5, 'LDAPS_CC4')

# %%
#Menampilkan outliers dalam bentuk grafik
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='LDAPS_Tmax_lapse')
fig.set_title('')
fig.set_ylabel('LDAPS_Tmax_lapse')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='LDAPS_Tmin_lapse')
fig.set_title('')
fig.set_ylabel('LDAPS_Tmin_lapse')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='LDAPS_WS')
fig.set_title('')
fig.set_ylabel('LDAPS_WS')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='LDAPS_LH')
fig.set_title('')
fig.set_ylabel('LDAPS_LH')
# Out:
# Text(0, 0.5, 'LDAPS_LH')

# %%
#Menampilkan outliers dalam bentuk grafik
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='Present_Tmax')
fig.set_title('')
fig.set_ylabel('Present_Tmax')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Present_Tmin')
fig.set_title('')
fig.set_ylabel('Present_Tmin')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='LDAPS_RHmin')
fig.set_title('')
fig.set_ylabel('LDAPS_RHmin')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='LDAPS_RHmax')
fig.set_title('')
fig.set_ylabel('LDAPS_RHmax')
# Out:
# Text(0, 0.5, 'LDAPS_RHmax')

# %%
#Menampilkan outliers dalam bentuk grafik
plt.figure(figsize=(15,10))


plt.subplot(2, 2, 1)
fig = df.boxplot(column='LDAPS_PPT1')
fig.set_title('')
fig.set_ylabel('LDAPS_PPT1')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='LDAPS_PPT2')
fig.set_title('')
fig.set_ylabel('LDAPS_PPT2')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='LDAPS_PPT3')
fig.set_title('')
fig.set_ylabel('LDAPS_PPT3')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='LDAPS_PPT4')
fig.set_title('')
fig.set_ylabel('LDAPS_PPT4')
# Out:
# Text(0, 0.5, 'LDAPS_PPT4')

# %%
#Menampilkan outliers dalam bentuk grafik
plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
fig = df.boxplot(column='DEM')
fig.set_title('')
fig.set_ylabel('DEM')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Slope')
fig.set_title('')
fig.set_ylabel('Slope')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='lat')
fig.set_title('')
fig.set_ylabel('lat')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='lon')
fig.set_title('')
fig.set_ylabel('lon')
# Out:
# Text(0, 0.5, 'lon')

# %% [markdown]
# ### Correlation

# %%
#Menampilkan kolerasi dari semua kolom data
korelasi=df.corr()
korelasi
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.617641    -0.204789    -0.298904
# Present_Tmin          0.617641      1.000000     0.127429    -0.011390
# LDAPS_RHmin          -0.204789      0.127429     1.000000     0.578957
# LDAPS_RHmax          -0.298904     -0.011390     0.578957     1.000000
# LDAPS_Tmax_lapse      0.575317      0.474117    -0.560126    -0.371869
# LDAPS_Tmin_lapse      0.628937      0.775355     0.092447    -0.111858
# LDAPS_WS             -0.116963     -0.039562     0.280282     0.124605
# LDAPS_LH              0.142356     -0.003559    -0.076371     0.236035
# LDAPS_CC1            -0.313095      0.088833     0.612246     0.433980
# LDAPS_CC2            -0.216844      0.093078     0.746088     0.391205
# LDAPS_CC3            -0.145216      0.000599     0.692760     0.229919
# LDAPS_CC4            -0.140544     -0.043186     0.513530     0.133581
# LDAPS_PPT1           -0.103633      0.118529     0.264141     0.263955
# LDAPS_PPT2           -0.095368      0.075146     0.392678     0.227462
# LDAPS_PPT3           -0.119521     -0.041609     0.241015     0.137192
# LDAPS_PPT4           -0.102367     -0.067789     0.165949     0.120064
# lat                  -0.050210     -0.083904     0.087334     0.198755
# lon                   0.013300     -0.038706    -0.073605     0.025463
# DEM                  -0.190972     -0.255770     0.102449     0.179357
# Slope                -0.100495     -0.143182     0.118823     0.220017
# Solar radiation      -0.027761      0.051220     0.249264     0.149501
# Next_Tmax             0.613971      0.480871    -0.437581    -0.281169
#
#                   LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  \
# Present_Tmax              0.575317          0.628937 -0.116963  0.142356
# Present_Tmin              0.474117          0.775355 -0.039562 -0.003559
# LDAPS_RHmin              -0.560126          0.092447  0.280282 -0.076371
# LDAPS_RHmax              -0.371869         -0.111858  0.124605  0.236035
# LDAPS_Tmax_lapse          1.000000          0.656094 -0.302015  0.053319
# LDAPS_Tmin_lapse          0.656094          1.000000 -0.127486 -0.130782
# LDAPS_WS                 -0.302015         -0.127486  1.000000  0.008196
# LDAPS_LH                  0.053319         -0.130782  0.008196  1.000000
# LDAPS_CC1                -0.434856          0.014577  0.283050 -0.152788
# LDAPS_CC2                -0.520931          0.049656  0.254903 -0.271878
# LDAPS_CC3                -0.536341         -0.039166  0.240997 -0.248421
# LDAPS_CC4                -0.423658         -0.078303  0.220470 -0.171351
# LDAPS_PPT1               -0.108394          0.043058  0.140473 -0.018751
# LDAPS_PPT2               -0.240155          0.003927  0.182045 -0.082045
# LDAPS_PPT3               -0.189093         -0.087622  0.163392  0.015613
# LDAPS_PPT4               -0.157402         -0.094439  0.138730  0.019383
# lat                      -0.039799         -0.096442  0.030184  0.141390
# lon                       0.095616         -0.016649 -0.063434  0.018711
# DEM                      -0.185072         -0.199866  0.188031  0.053179
# Slope                    -0.159213         -0.183053  0.160826  0.085917
# Solar radiation           0.047155          0.160584  0.118097 -0.052418
# Next_Tmax                 0.836222          0.595602 -0.341725  0.164475
#
#                   LDAPS_CC1  LDAPS_CC2  ...  LDAPS_PPT1  LDAPS_PPT2  \
# Present_Tmax      -0.313095  -0.216844  ...   -0.103633   -0.095368
# Present_Tmin       0.088833   0.093078  ...    0.118529    0.075146
# LDAPS_RHmin        0.612246   0.746088  ...    0.264141    0.392678
# LDAPS_RHmax        0.433980   0.391205  ...    0.263955    0.227462
# LDAPS_Tmax_lapse  -0.434856  -0.520931  ...   -0.108394   -0.240155
# LDAPS_Tmin_lapse   0.014577   0.049656  ...    0.043058    0.003927
# LDAPS_WS           0.283050   0.254903  ...    0.140473    0.182045
# LDAPS_LH          -0.152788  -0.271878  ...   -0.018751   -0.082045
# LDAPS_CC1          1.000000   0.780367  ...    0.445859    0.390564
# LDAPS_CC2          0.780367   1.000000  ...    0.309335    0.479072
# LDAPS_CC3          0.517944   0.725412  ...    0.168539    0.344875
# LDAPS_CC4          0.355344   0.523589  ...    0.125853    0.293950
# LDAPS_PPT1         0.445859   0.309335  ...    1.000000    0.384489
# LDAPS_PPT2         0.390564   0.479072  ...    0.384489    1.000000
# LDAPS_PPT3         0.163294   0.236709  ...    0.034672    0.227502
# LDAPS_PPT4         0.080691   0.153602  ...    0.021576    0.134254
# lat               -0.011685  -0.000619  ...    0.001528    0.020590
# lon               -0.003180   0.002977  ...    0.002703    0.016334
# DEM               -0.016242  -0.016332  ...    0.006904    0.004927
# Slope             -0.028106  -0.027057  ...    0.006241    0.002765
# Solar radiation    0.218967   0.173158  ...    0.086896    0.109256
# Next_Tmax         -0.452924  -0.491555  ...   -0.117659   -0.178207
#
#                   LDAPS_PPT3  LDAPS_PPT4       lat       lon       DEM  \
# Present_Tmax       -0.119521   -0.102367 -0.050210  0.013300 -0.190972
# Present_Tmin       -0.041609   -0.067789 -0.083904 -0.038706 -0.255770
# LDAPS_RHmin         0.241015    0.165949  0.087334 -0.073605  0.102449
# LDAPS_RHmax         0.137192    0.120064  0.198755  0.025463  0.179357
# LDAPS_Tmax_lapse   -0.189093   -0.157402 -0.039799  0.095616 -0.185072
# LDAPS_Tmin_lapse   -0.087622   -0.094439 -0.096442 -0.016649 -0.199866
# LDAPS_WS            0.163392    0.138730  0.030184 -0.063434  0.188031
# LDAPS_LH            0.015613    0.019383  0.141390  0.018711  0.053179
# LDAPS_CC1           0.163294    0.080691 -0.011685 -0.003180 -0.016242
# LDAPS_CC2           0.236709    0.153602 -0.000619  0.002977 -0.016332
# LDAPS_CC3           0.342615    0.306105  0.004294  0.019633 -0.000553
# LDAPS_CC4           0.270680    0.380740 -0.003376 -0.000970 -0.006445
# LDAPS_PPT1          0.034672    0.021576  0.001528  0.002703  0.006904
# LDAPS_PPT2          0.227502    0.134254  0.020590  0.016334  0.004927
# LDAPS_PPT3          1.000000    0.322160  0.035713  0.017366  0.012791
# LDAPS_PPT4          0.322160    1.000000  0.014451  0.042914 -0.006027
# lat                 0.035713    0.014451  1.000000  0.288664  0.042448
# lon                 0.017366    0.042914  0.288664  1.000000  0.009928
# DEM                 0.012791   -0.006027  0.042448  0.009928  1.000000
# Slope               0.017999   -0.004059  0.079766  0.037086  0.783402
# Solar radiation    -0.050569    0.041281  0.036813  0.002223  0.057930
# Next_Tmax          -0.199408   -0.179366 -0.049624  0.009330 -0.175778
#
#                      Slope  Solar radiation  Next_Tmax
# Present_Tmax     -0.100495        -0.027761   0.613971
# Present_Tmin     -0.143182         0.051220   0.480871
# LDAPS_RHmin       0.118823         0.249264  -0.437581
# LDAPS_RHmax       0.220017         0.149501  -0.281169
# LDAPS_Tmax_lapse -0.159213         0.047155   0.836222
# LDAPS_Tmin_lapse -0.183053         0.160584   0.595602
# LDAPS_WS          0.160826         0.118097  -0.341725
# LDAPS_LH          0.085917        -0.052418   0.164475
# LDAPS_CC1        -0.028106         0.218967  -0.452924
# LDAPS_CC2        -0.027057         0.173158  -0.491555
# LDAPS_CC3        -0.005716         0.126633  -0.517393
# LDAPS_CC4        -0.016099         0.130544  -0.449654
# LDAPS_PPT1        0.006241         0.086896  -0.117659
# LDAPS_PPT2        0.002765         0.109256  -0.178207
# LDAPS_PPT3        0.017999        -0.050569  -0.199408
# LDAPS_PPT4       -0.004059         0.041281  -0.179366
# lat               0.079766         0.036813  -0.049624
# lon               0.037086         0.002223   0.009330
# DEM               0.783402         0.057930  -0.175778
# Slope             1.000000         0.032197  -0.097947
# Solar radiation   0.032197         1.000000   0.004435
# Next_Tmax        -0.097947         0.004435   1.000000
#
# [22 rows x 22 columns]

# %%
#Menampilkan visualisasi kolerasi data
correlation = df.corr()
plt.figure(figsize=(20,20))
plt.title('Correlation Heatmap of Covid-19 Dataset', fontsize=20)
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)           
plt.show()
#sns.heatmap(kolerasi);

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(y = df['LDAPS_Tmax_lapse'],  x = df['Next_Tmax'])
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(y = df['LDAPS_CC2'],  x = df['LDAPS_RHmin'])
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(y = df['LDAPS_CC3'],  x = df['LDAPS_CC4'])
plt.show()

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Missing value

# %%
df['Present_Tmax'] = df['Present_Tmax'].fillna(df['Present_Tmax'].mean())
df['Present_Tmin'] = df['Present_Tmin'].fillna(df['Present_Tmin'].mean())
df['LDAPS_RHmin'] = df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())
df['LDAPS_RHmax'] = df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].mean())
df['LDAPS_Tmax_lapse'] = df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())
df['LDAPS_Tmin_lapse'] = df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())
df['LDAPS_WS'] = df['LDAPS_WS'].fillna(df['LDAPS_WS'].mean())
df['LDAPS_LH'] = df['LDAPS_LH'].fillna(df['LDAPS_LH'].mean())
df['LDAPS_CC1'] = df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].mean())
df['LDAPS_CC2'] = df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].mean())
df['LDAPS_CC3'] = df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].mean())
df['LDAPS_CC4'] = df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].mean())
df['LDAPS_PPT1'] = df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())
df['LDAPS_PPT2'] = df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())
df['LDAPS_PPT3'] = df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())
df['LDAPS_PPT4'] = df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())
df['Next_Tmax'] = df['Next_Tmax'].fillna(df['Next_Tmax'].mean())

# %%
df.isnull().sum()
# Out:
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# dtype: int64

# %% [markdown]
# ### Handle outlier

# %%
df.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          30.3          21.1    61.741207    87.262192         26.629430
# 1          29.3          20.9    85.943954    97.694801         25.380395
# 2          29.5          22.2    32.008099    69.966370         31.991670
# 3          32.6          21.2    60.070614    91.244827         27.043616
# 4          33.0          27.6    62.508846    86.983963         31.529577
#
#    LDAPS_Tmin_lapse   LDAPS_WS   LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.075077   4.263528  21.399026   0.297776   0.616711  ...
# 1         23.275475   8.697955  53.165713   0.901123   0.867350  ...
# 2         21.475995  10.461500  37.582673   0.012838   0.086090  ...
# 3         23.338373  15.686361  95.842065   0.622580   0.388476  ...
# 4         27.307177   6.493082  49.887497   0.438076   0.458994  ...
#
#    LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0    0.000000    0.000000    0.000479    0.000000  37.5776  126.938   75.0924
# 1    2.642577    0.261794    0.288428    2.315489  37.5507  126.988  132.1180
# 2    0.000000    0.000000    0.000000    0.000000  37.5507  126.937   30.0464
# 3    0.285723    0.335796    0.000000    0.000000  37.6046  127.032   44.7624
# 4    0.000000    0.000000    0.000000    0.000000  37.5102  127.042   54.6384
#
#     Slope  Solar radiation  Next_Tmax
# 0  1.7678      5131.667480       26.4
# 1  0.5931      5918.901367       25.6
# 2  0.8552      5222.419434       30.6
# 3  0.5141      5558.630371       27.2
# 4  0.1457      5635.460449       32.8
#
# [5 rows x 22 columns]

# %%
#Mengatasi Outlier
features_with_outliers = ['Present_Tmax','Present_Tmin', 'LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','DEM', 'Slope','Next_Tmax','LDAPS_WS','LDAPS_WS','LDAPS_RHmax']
for feature in features_with_outliers:
    q1 = df[feature].quantile(0.25)
    q3 = df[feature].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    df.loc[df[feature]<lower_limit,feature]=lower_limit
    df.loc[df[feature]>upper_limit,feature]=upper_limit

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# ### Splitting

# %%
#Membagi variabel independen dan dependen menggunakan x dan y
x = df.drop(columns='Next_Tmax')
y = df['Next_Tmax']

# %% [markdown]
# ### MinMax Scalling

# %%
#Melakukan standarisasi 
min_max_scaler = preprocessing.MinMaxScaler()
x_train_minmax = min_max_scaler.fit_transform(x)
x_train_minmax
# Out:
# array([[0.54658385, 0.328125  , 0.53278934, ..., 0.66611867, 0.42649291,
#         0.48224047],
#        [0.48447205, 0.3125    , 0.84020362, ..., 1.        , 0.12637094,
#         0.95551538],
#        [0.49689441, 0.4140625 , 0.15513047, ..., 0.18772528, 0.1933344 ,
#         0.53679938],
#        ...,
#        [0.59006211, 0.609375  , 0.41935033, ..., 0.7425707 , 0.55170767,
#         0.54839395],
#        [0.34161491, 0.5546875 , 0.68145488, ..., 0.17342637, 0.13408669,
#         0.82048164],
#        [0.45341615, 0.4765625 , 0.22124212, ..., 0.34401079, 0.10618738,
#         0.24147117]])

# %%
df.head()
# Out:
#    Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0          30.3          21.1    61.741207    87.262192         26.629430
# 1          29.3          20.9    85.943954    97.694801         25.380395
# 2          29.5          22.2    32.008099    70.255321         31.991670
# 3          32.6          21.2    60.070614    91.244827         27.043616
# 4          33.0          27.6    62.508846    86.983963         31.529577
#
#    LDAPS_Tmin_lapse   LDAPS_WS   LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# 0         23.075077   4.263528  21.399026   0.297776   0.616711  ...
# 1         23.275475   8.697955  53.165713   0.901123   0.867350  ...
# 2         21.475995  10.461500  37.582673   0.012838   0.086090  ...
# 3         23.338373  11.393358  95.842065   0.622580   0.388476  ...
# 4         27.307177   6.493082  49.887497   0.438076   0.458994  ...
#
#    LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0    0.000000    0.000000    0.000479    0.000000  37.5776  126.938   75.0924
# 1    2.642577    0.261794    0.288428    2.315489  37.5507  126.988  106.5310
# 2    0.000000    0.000000    0.000000    0.000000  37.5507  126.937   30.0464
# 3    0.285723    0.335796    0.000000    0.000000  37.6046  127.032   44.7624
# 4    0.000000    0.000000    0.000000    0.000000  37.5102  127.042   54.6384
#
#     Slope  Solar radiation  Next_Tmax
# 0  1.7678      5131.667480       26.4
# 1  0.5931      5918.901367       25.6
# 2  0.8552      5222.419434       30.6
# 3  0.5141      5558.630371       27.2
# 4  0.1457      5635.460449       32.8
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ### Model training

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Accuracy Score

# %%
#Untuk memprediksi x dan y
y_pred = model.predict(x)

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y, y_pred)
mse = metrics.mean_squared_error(y, y_pred)
r2 = metrics.r2_score(y, y_pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 1.143211917031618
# MSE is 2.2922576093145657
# R2 score is 0.7635574725925666

# %%
fig, ax = plt.subplots()
ax.scatter(y_pred, y, edgecolors=(0, 0, 1))
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', lw=3)
ax.set_xlabel('Pred')
ax.set_ylabel('Actual')
plt.show()

# %%
#Untuk mencari akurasi score dari model kita
model.score(x, y)
# Out:
# 0.7635574725925666
