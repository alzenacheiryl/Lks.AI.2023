# %% [markdown]
# # Analisis Data

# %%
#Import library yang dibutuhkan 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#Membaca datafile kita dan mengambil beberapa kolom yg dibutuhkan saja
df = pd.read_csv('cardata.csv', usecols=['Present_Price','Year','Kms_Driven','Owner'])

# %%
#Menampilkan datafile
df.head()
# Out:
#   Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0     ritz  maruti suzuki  2014           3.35           5.59       27000
# 1      sx4  maruti suzuki  2013           4.75           9.54       43000
# 2     ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3  wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4    swift  maruti suzuki  2014           4.60           6.87       42450
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Diesel      Dealer       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %%
#Untuk mengetahui jumlah baris dan kolom datafile kita
df.shape
# Out:
# (301, 4)

# %%
#Untuk menampilkan info datafile kita meliputi baris,kolom,tipe data,memori yg digunakan,dll
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Present_Price  301 non-null    float64
#  2   Kms_Driven     301 non-null    int64
#  3   Owner          301 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 9.5 KB

# %%
#Untuk melihat statiska datafile kita meliputi rata-rata,minimum,maximum,dll
df.describe()
# Out:
#               Year  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       7.628472   36947.205980    0.043189
# std       2.891554       8.644115   38886.883882    0.247915
# min    2003.000000       0.320000     500.000000    0.000000
# 25%    2012.000000       1.200000   15000.000000    0.000000
# 50%    2014.000000       6.400000   32000.000000    0.000000
# 75%    2016.000000       9.900000   48767.000000    0.000000
# max    2018.000000      92.600000  500000.000000    3.000000

# %%
#Untuk mengetahui missing value atau nilai yg kosong 
df.isnull().sum()
# Out:
# Year             0
# Present_Price    0
# Kms_Driven       0
# Owner            0
# dtype: int64

# %%
#Analisis untuk melihat distribusi dari masing-masing kolom dalam bentuk grafik dan box
f = plt.figure(figsize=(50,20))

f.add_subplot(1,2,1)
sns.countplot(df['Year'])

f.add_subplot(1,2,2)
plt.boxplot(df['Year'])
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Analisis untuk melihat distribusi dari masing-masing kolom dalam bentuk grafik dan box
f = plt.figure(figsize=(50,20))

f.add_subplot(1,2,1)
sns.countplot(df['Present_Price'])

f.add_subplot(1,2,2)
plt.boxplot(df['Present_Price'])
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Untuk melihat sencity/pemerataan distribusi dari harga
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['Present_Price'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['Present_Price'])
plt.show()

# %%
#Untuk mengetahui hubungan antara independen dan dependen ariabel 
f = plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['Year','Present_Price','Kms_Driven','Owner'], y_vars=['Present_Price'], size=5, aspect=0.75)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Untuk mengetahui nilai korelasi dari independent dan dependen variabel
df.corr().style.background_gradient().set_precision(1)
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_2304/171237905.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient().set_precision(1)
# <style type="text/css">
# #T_3e49c_row0_col0, #T_3e49c_row1_col1, #T_3e49c_row2_col2, #T_3e49c_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3e49c_row0_col1, #T_3e49c_row0_col2, #T_3e49c_row0_col3, #T_3e49c_row2_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3e49c_row1_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_3e49c_row1_col2 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_3e49c_row1_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_3e49c_row2_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_3e49c_row2_col3 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_3e49c_row3_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_3e49c_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_3e49c_row3_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# </style>
# <table id="T_3e49c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >Present_Price</th>
#       <th class="col_heading level0 col2" >Kms_Driven</th>
#       <th class="col_heading level0 col3" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e49c_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_3e49c_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_3e49c_row0_col1" class="data row0 col1" >-0.0</td>
#       <td id="T_3e49c_row0_col2" class="data row0 col2" >-0.5</td>
#       <td id="T_3e49c_row0_col3" class="data row0 col3" >-0.2</td>
#     </tr>
#     <tr>
#       <th id="T_3e49c_level0_row1" class="row_heading level0 row1" >Present_Price</th>
#       <td id="T_3e49c_row1_col0" class="data row1 col0" >-0.0</td>
#       <td id="T_3e49c_row1_col1" class="data row1 col1" >1.0</td>
#       <td id="T_3e49c_row1_col2" class="data row1 col2" >0.2</td>
#       <td id="T_3e49c_row1_col3" class="data row1 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_3e49c_level0_row2" class="row_heading level0 row2" >Kms_Driven</th>
#       <td id="T_3e49c_row2_col0" class="data row2 col0" >-0.5</td>
#       <td id="T_3e49c_row2_col1" class="data row2 col1" >0.2</td>
#       <td id="T_3e49c_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_3e49c_row2_col3" class="data row2 col3" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_3e49c_level0_row3" class="row_heading level0 row3" >Owner</th>
#       <td id="T_3e49c_row3_col0" class="data row3 col0" >-0.2</td>
#       <td id="T_3e49c_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_3e49c_row3_col2" class="data row3 col2" >0.1</td>
#       <td id="T_3e49c_row3_col3" class="data row3 col3" >1.0</td>
#     </tr>
#   </tbody>
# </table>
