# %% [raw]
# # Data Preparation

# %%
#Import libary-libary yang digunakan
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Menload data
df = pd.read_csv("Covid Data.csv")
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %% [markdown]
# Menurut analisis dari data tersebut bisa memprediksi kematian seseorang, iya atau tidak jika memiliki beberapa penyakit tersebut.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (1048575, 21)

# %% [markdown]
# #Menghapus variabel Date
# df.drop('DATE_DIED', axis=1, inplace=True)

# %%
#Mengecek kolom dan baris data
df.shape
# Out:
# (1048575, 21)

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
#Menampilkan deskripsi data
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
#Mengcek Missing Value
missing_values = df.isnull().sum()
missing_values
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
#Visualisasi missing values
fig = plt.figure(figsize=(35,10))
plt.bar(df.columns, missing_values)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
addlabels(df.columns, missing_values)

fig.suptitle('Visualisasi Missing Values dari Dataset', fontsize=20)
plt.xlabel('xlabel', fontsize=10)
plt.ylabel('ylabel', fontsize=10)
# Out:
# Text(0, 0.5, 'ylabel')

# %%
#Melihat Unique Values
unique_values = df.nunique()
unique_values
# Out:
# USMER                     2
# MEDICAL_UNIT             13
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED               401
# INTUBED                   4
# PNEUMONIA                 3
# AGE                     121
# PREGNANT                  4
# DIABETES                  3
# COPD                      3
# ASTHMA                    3
# INMSUPR                   3
# HIPERTENSION              3
# OTHER_DISEASE             3
# CARDIOVASCULAR            3
# OBESITY                   3
# RENAL_CHRONIC             3
# TOBACCO                   3
# CLASIFFICATION_FINAL      7
# ICU                       4
# dtype: int64

# %%
#Visualisasi Unique Values
fig = plt.figure(figsize=(35,10))
plt.bar(df.columns, unique_values)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
addlabels(df.columns, unique_values)

fig.suptitle('Visualisasi Unique Values dari Dataset', fontsize=20)
plt.xlabel('xlabel', fontsize=10)
plt.ylabel('ylabel', fontsize=10)
# Out:
# Text(0, 0.5, 'ylabel')

# %%
#Menampilkan kolerasi dalam bentuk angkanya aja dari semua kolom data
kolerasi=df.corr()
kolerasi
# Out:
#                          USMER  MEDICAL_UNIT       SEX  PATIENT_TYPE  \
# USMER                 1.000000      0.127927 -0.001126     -0.190570
# MEDICAL_UNIT          0.127927      1.000000  0.001475     -0.205413
# SEX                  -0.001126      0.001475  1.000000      0.089505
# PATIENT_TYPE         -0.190570     -0.205413  0.089505      1.000000
# INTUBED               0.175457      0.205243 -0.089943     -0.976335
# PNEUMONIA            -0.154950     -0.046433 -0.012131      0.022966
# AGE                  -0.045088     -0.082223  0.028367      0.315193
# PREGNANT             -0.001469      0.005300  0.992713      0.088340
# DIABETES              0.014704      0.019523  0.008888      0.008743
# COPD                  0.011030      0.014209  0.009372      0.019548
# ASTHMA                0.010814      0.013312  0.010415      0.023042
# INMSUPR               0.003234      0.011785  0.007999      0.024924
# HIPERTENSION          0.014830      0.020964  0.009257      0.006852
# ...

# %%
#Menampilkan visualisasi kolerasi data
correlation = df.corr()
plt.figure(figsize=(20,20))
plt.title('Correlation Heatmap of Rain in Australia Dataset', fontsize=20)
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)           
plt.show()
#sns.heatmap(kolerasi);

# %% [markdown]
# Dari heatmap diatas, semakin cerah warna pada box menunjukan semakin tinggi nilai korelasi antara 2 variabel.
# a. Variabel pregnant dengan sex
# b. Variabel asthma dengan copd
# c. Variabel renal_chronic dengan cardiovascular
# d. Variabel asthma dengan renal_chronic

# %% [markdown]
# # Data Preprocessing

# %%
#Mengganti nama variabel
df = df.rename(columns = {"DATE_DIED": "DIED"})

# %%
#Cara mengganti nilai 97, 98, 99 ke NaN
df = df.replace(97, np.nan, regex=True)
df = df.replace(98, np.nan, regex=True)
df = df.replace(99, np.nan, regex=True)

# %%
df['DIED'].value_counts()
# Out:
# 9999-99-99    971633
# 06/07/2020      1000
# 07/07/2020       996
# 13/07/2020       990
# 16/06/2020       979
#                ...
# 24/11/2020         1
# 17/12/2020         1
# 08/12/2020         1
# 16/03/2021         1
# 22/04/2021         1
# Name: DIED, Length: 401, dtype: int64

# %%
unique_values = df['DIED'].unique()

# %% [markdown]
# # Cara save numpy array ke file TXT
# file = open("E:\\Downloads\\Covid\\test_file.txt", "w+")
#
# # Saving the array in a text file
# content = str(unique_values)
# file.write(content)
# file.close()

# %%
df['DIED'] = df['DIED'].replace("9999-99-99", "No", regex=True)

# %%
df['DIED'] = df['DIED'].replace(dict.fromkeys(['03/05/2020','03/06/2020','09/06/2020','12/06/2020','21/06/2020','26/02/2020','05/04/2020','08/05/2020','20/05/2020'
,'17/07/2020','13/01/2020','22/01/2020','29/01/2020','13/02/2020','18/02/2020','19/02/2020','20/02/2020','24/02/2020','04/03/2020'
,'07/03/2020','12/03/2020','14/03/2020','18/03/2020','27/03/2020','28/03/2020','29/03/2020','02/04/2020','06/04/2020','07/04/2020'
,'08/04/2020','09/04/2020','10/04/2020','11/04/2020','12/04/2020','13/04/2020','14/04/2020','15/04/2020','16/04/2020','17/04/2020'
,'18/04/2020','20/04/2020','21/04/2020','22/04/2020','23/04/2020','24/04/2020','25/04/2020','26/04/2020','27/04/2020','28/04/2020'
,'29/04/2020','30/04/2020','01/05/2020','02/05/2020','04/05/2020','05/05/2020','06/05/2020','07/05/2020','09/05/2020','10/05/2020'
,'11/05/2020','12/05/2020','13/05/2020','14/05/2020','15/05/2020','16/05/2020','17/05/2020','18/05/2020','19/05/2020','21/05/2020'
,'22/05/2020','23/05/2020','24/05/2020','25/05/2020','26/05/2020','27/05/2020','28/05/2020','29/05/2020','30/05/2020','31/05/2020'
,'01/06/2020','02/06/2020','04/06/2020','05/06/2020','06/06/2020','07/06/2020','08/06/2020','10/06/2020','11/06/2020','13/06/2020'
,'14/06/2020','15/06/2020','16/06/2020','17/06/2020','18/06/2020','19/06/2020','20/06/2020','22/06/2020','23/06/2020','24/06/2020'
,'25/06/2020','26/06/2020','27/06/2020','28/06/2020','29/06/2020','30/06/2020','01/07/2020','02/07/2020','03/07/2020','04/07/2020'
,'05/07/2020','06/07/2020','07/07/2020','08/07/2020','09/07/2020','10/07/2020','11/07/2020','12/07/2020','13/07/2020','14/07/2020'
,'15/07/2020','16/07/2020','18/07/2020','19/07/2020','20/07/2020','21/07/2020','22/07/2020','23/07/2020','24/07/2020','25/07/2020'
,'26/07/2020','27/07/2020','28/07/2020','29/07/2020','30/07/2020','31/07/2020','01/08/2020','02/08/2020','03/08/2020','04/08/2020'
,'05/08/2020','06/08/2020','07/08/2020','08/08/2020','09/08/2020','10/08/2020','12/08/2020','14/08/2020','17/08/2020','18/08/2020'
,'19/08/2020','20/08/2020','25/08/2020','02/09/2020','13/09/2020','28/09/2020','27/10/2020','08/12/2020','17/12/2020','27/04/2021'
,'01/05/2021','02/01/2020','03/01/2020','04/01/2020','05/01/2020','06/01/2020','07/01/2020','08/01/2020','09/01/2020','10/01/2020'
,'11/01/2020','12/01/2020','14/01/2020','15/01/2020','16/01/2020','17/01/2020','18/01/2020','19/01/2020','20/01/2020','21/01/2020'
,'23/01/2020','24/01/2020','25/01/2020','26/01/2020','27/01/2020','28/01/2020','30/01/2020','31/01/2020','01/02/2020','02/02/2020'
,'03/02/2020','04/02/2020','05/02/2020','06/02/2020','07/02/2020','08/02/2020','09/02/2020','10/02/2020','11/02/2020','12/02/2020'
,'14/02/2020','15/02/2020','16/02/2020','17/02/2020','21/02/2020','22/02/2020','23/02/2020','25/02/2020','27/02/2020','28/02/2020'
,'29/02/2020','01/03/2020','02/03/2020','03/03/2020','05/03/2020','06/03/2020','08/03/2020','09/03/2020','10/03/2020','11/03/2020'
,'13/03/2020','15/03/2020','16/03/2020','17/03/2020','19/03/2020','20/03/2020','21/03/2020','22/03/2020','23/03/2020','24/03/2020'
,'25/03/2020','26/03/2020','30/03/2020','31/03/2020','01/04/2020','03/04/2020','04/04/2020','19/04/2020','11/08/2020','13/08/2020'
,'15/08/2020','16/08/2020','21/08/2020','22/08/2020','23/08/2020','24/08/2020','26/08/2020','27/08/2020','28/08/2020','29/08/2020'
,'30/08/2020','31/08/2020','01/09/2020','03/09/2020','04/09/2020','05/09/2020','06/09/2020','07/09/2020','08/09/2020','09/09/2020'
,'11/09/2020','14/09/2020','16/09/2020','17/09/2020','18/09/2020','19/09/2020','20/09/2020','21/09/2020','22/09/2020','23/09/2020'
,'24/09/2020','27/09/2020','29/09/2020','04/10/2020','05/10/2020','12/10/2020','14/10/2020','16/10/2020','18/10/2020','20/10/2020'
,'23/10/2020','25/10/2020','26/10/2020','30/10/2020','04/11/2020','06/11/2020','08/11/2020','12/11/2020','14/11/2020','15/11/2020'
,'23/11/2020','24/11/2020','05/12/2020','30/12/2020','10/01/2021','14/01/2021','15/01/2021','19/01/2021','20/01/2021','21/01/2021'
,'24/01/2021','25/01/2021','27/01/2021','28/01/2021','31/01/2021','01/02/2021','03/02/2021','04/02/2021','05/02/2021','06/02/2021'
,'08/02/2021','10/02/2021','11/02/2021','12/02/2021','18/02/2021','20/02/2021','24/02/2021','25/02/2021','26/02/2021','27/02/2021'
,'07/03/2021','08/03/2021','29/03/2021','30/03/2021','01/04/2021','12/04/2021','14/04/2021','15/04/2021','16/04/2021','17/04/2021'
,'18/04/2021','25/04/2021','26/04/2021','28/04/2021','29/04/2021','30/04/2021','02/05/2021','18/12/2020','17/10/2020','07/12/2020'
,'16/12/2020','19/12/2020','06/01/2021','17/02/2021','16/03/2021','17/03/2021','18/03/2021','20/03/2021','22/03/2021','23/03/2021'
,'24/03/2021','09/04/2021','10/04/2021','19/04/2021','24/04/2021','10/09/2020','31/10/2020','15/12/2020','24/12/2020','11/01/2021'
,'23/02/2021','03/04/2021','20/04/2021','26/12/2020','19/03/2021','12/09/2020','15/09/2020','25/09/2020','06/10/2020','07/10/2020'
,'10/10/2020','13/10/2020','22/10/2020','22/11/2020','25/11/2020','27/11/2020','03/12/2020','20/12/2020','22/12/2020','25/12/2020'
,'28/12/2020','01/01/2021','02/01/2021','07/01/2021','22/01/2021','26/01/2021','07/02/2021','14/02/2021','19/02/2021','22/02/2021'
,'10/03/2021','11/03/2021','14/03/2021','26/03/2021','27/03/2021','28/03/2021','31/03/2021','02/04/2021','06/04/2021','13/04/2021'
,'22/04/2021'], 'Yes'))

# %%
df.tail()
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DIED  INTUBED  PNEUMONIA  \
# 1048570      2            13    2             1   No      NaN        2.0
# 1048571      1            13    2             2   No      2.0        2.0
# 1048572      2            13    2             1   No      NaN        2.0
# 1048573      2            13    2             1   No      NaN        2.0
# 1048574      2            13    2             1   No      NaN        2.0
#
#           AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  \
# 1048570  40.0       NaN       2.0  ...     2.0      2.0           2.0
# 1048571  51.0       NaN       2.0  ...     2.0      2.0           1.0
# 1048572  55.0       NaN       2.0  ...     2.0      2.0           2.0
# 1048573  28.0       NaN       2.0  ...     2.0      2.0           2.0
# 1048574  52.0       NaN       2.0  ...     2.0      2.0           2.0
#
#          OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# ...

# %%
#Mengganti tipe data String menjadi numerik pada kolom RainToday
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['DIED'] = le.fit_transform(df['DIED'])

# %%
df['DIED'].value_counts()
# Out:
# 0    971633
# 1     76942
# Name: DIED, dtype: int64

# %% [markdown]
# 0 -> ini menyatakan pasien belum meninggal, 1 -> ini menyatakan pasien sudah meninggal

# %%
df.isnull().sum()
# Out:
# USMER                        0
# MEDICAL_UNIT                 0
# SEX                          0
# PATIENT_TYPE                 0
# DIED                         0
# INTUBED                 855869
# PNEUMONIA                16003
# AGE                        345
# PREGNANT                527265
# DIABETES                  3338
# COPD                      3003
# ASTHMA                    2979
# INMSUPR                   3404
# HIPERTENSION              3104
# OTHER_DISEASE             5045
# CARDIOVASCULAR            3076
# OBESITY                   3032
# RENAL_CHRONIC             3006
# TOBACCO                   3220
# CLASIFFICATION_FINAL         0
# ICU                     856032
# dtype: int64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,8))
ax.hist(df['INTUBED'])
plt.show()

# %%
df['INTUBED'] = df['INTUBED'].fillna(df.groupby("DIED")['INTUBED'].transform("mean"))
df['PNEUMONIA'] = df['PNEUMONIA'].fillna(df.groupby("DIED")['PNEUMONIA'].transform("mean"))
df['AGE'] = df['AGE'].fillna(df.groupby("DIED")['AGE'].transform("mean"))
df['PREGNANT'] = df['PREGNANT'].fillna(df.groupby("DIED")['PREGNANT'].transform("mean"))
df['DIABETES'] = df['DIABETES'].fillna(df.groupby("DIED")['DIABETES'].transform("mean"))
df['COPD'] = df['COPD'].fillna(df.groupby("DIED")['COPD'].transform("mean"))
df['ASTHMA'] = df['ASTHMA'].fillna(df.groupby("DIED")['ASTHMA'].transform("mean"))
df['INMSUPR'] = df['INMSUPR'].fillna(df.groupby("DIED")['INMSUPR'].transform("mean"))
df['HIPERTENSION'] = df['HIPERTENSION'].fillna(df.groupby("DIED")['HIPERTENSION'].transform("mean"))
df['OTHER_DISEASE'] = df['OTHER_DISEASE'].fillna(df.groupby("DIED")['OTHER_DISEASE'].transform("mean"))
df['CARDIOVASCULAR'] = df['CARDIOVASCULAR'].fillna(df.groupby("DIED")['CARDIOVASCULAR'].transform("mean"))
df['OBESITY'] = df['OBESITY'].fillna(df.groupby("DIED")['OBESITY'].transform("mean"))
df['RENAL_CHRONIC'] = df['RENAL_CHRONIC'].fillna(df.groupby("DIED")['RENAL_CHRONIC'].transform("mean"))
df['TOBACCO'] = df['TOBACCO'].fillna(df.groupby("DIED")['TOBACCO'].transform("mean"))
df['ICU'] = df['ICU'].fillna(df.groupby("DIED")['ICU'].transform("mean"))

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DIED                    0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %% [markdown]
# ## Scalling

# %%
#Mendefinisikan nilai x dan y
X = df.drop(['DIED'], axis=1)
y = df['DIED']

# %%
cols = X.columns

# %%
#Normalisasi
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X)
X_test = scaler.transform(X)

# %% [markdown]
# # Training & Testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
iris = load_iris()

# fit the model
model = clf.fit(X_train, y_train)

# %%
#Training 80%
print(X.shape)
print(X_train.shape)
print(X_test.shape)

#Testing 20%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1048575, 20)
# (838860, 20)
# (209715, 20)
# (1048575,)
# (838860,)
# (209715,)

# %%
# check missing values in X_train

X_train.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838860 entries, 592908 to 985772
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   USMER                 838860 non-null  int64
#  1   MEDICAL_UNIT          838860 non-null  int64
#  2   SEX                   838860 non-null  int64
#  3   PATIENT_TYPE          838860 non-null  int64
#  4   INTUBED               838860 non-null  float64
#  5   PNEUMONIA             838860 non-null  float64
#  6   AGE                   838860 non-null  float64
#  7   PREGNANT              838860 non-null  float64
#  8   DIABETES              838860 non-null  float64
#  9   COPD                  838860 non-null  float64
#  10  ASTHMA                838860 non-null  float64
#  11  INMSUPR               838860 non-null  float64
#  12  HIPERTENSION          838860 non-null  float64
#  13  OTHER_DISEASE         838860 non-null  float64
# ...

# %%
# check missing values in X_test

X_test.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
# check data types in X_train

X_train.dtypes
# Out:
# USMER                     int64
# MEDICAL_UNIT              int64
# SEX                       int64
# PATIENT_TYPE              int64
# INTUBED                 float64
# PNEUMONIA               float64
# AGE                     float64
# PREGNANT                float64
# DIABETES                float64
# COPD                    float64
# ASTHMA                  float64
# INMSUPR                 float64
# HIPERTENSION            float64
# OTHER_DISEASE           float64
# CARDIOVASCULAR          float64
# OBESITY                 float64
# RENAL_CHRONIC           float64
# TOBACCO                 float64
# CLASIFFICATION_FINAL      int64
# ICU                     float64
# dtype: object

# %%
y_pred_test = clf.predict(X_test)

y_pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_pred_train = clf.predict(X_train)

y_pred_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
clf.predict_proba(X_test)[:,0]
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
clf.predict_proba(X_test)[:,1]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf.score(X_test, y_test)))
# Out:
# Training set score: 0.9934
# Test set score: 0.9807

# %% [markdown]
# # GUI

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DIED   INTUBED  PNEUMONIA   AGE  \
# 0      2             1    1             1     1  1.611941        1.0  65.0
# 1      2             1    2             1     1  1.611941        1.0  72.0
# 2      2             1    2             2     1  1.000000        2.0  55.0
# 3      2             1    1             1     1  1.611941        2.0  53.0
# 4      2             1    2             1     1  1.611941        2.0  68.0
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0  2.000000       2.0  ...     2.0      2.0           1.0            2.0
# 1  1.996744       2.0  ...     2.0      2.0           1.0            2.0
# 2  1.996744       1.0  ...     2.0      2.0           2.0            2.0
# 3  2.000000       2.0  ...     2.0      2.0           2.0            2.0
# 4  1.996744       1.0  ...     2.0      2.0           1.0            2.0
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  \
# ...

# %%
import gradio as gr

# %%
print(df.columns)
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
a = pd.DataFrame({'a':[1,2], 'b':[3,4]})
a
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
#create a function for gradio
def died(USMER, MEDICAL_UNIT, SEX, PATIENT_TYPE, INTUBED, PNEUMONIA, AGE, PREGNANT, DIABETES, COPD, ASTHMA, INMSUPR, HIPERTENSION, OTHER_DISEASE, CARDIOVASCULAR, OBESITY, RENAL_CHRONIC, TOBACCO, CLASIFFICATION_FINAL, ICU):
    df = pd.DataFrame({'USMER':[USMER], 'MEDICAL_UNIT':[MEDICAL_UNIT],'SEX':[SEX],'PATIENT_TYPE':[PATIENT_TYPE],'INTUBED':[INTUBED],'PNEUMONIA':[PNEUMONIA],'AGE':[AGE],'PREGNANT':[PREGNANT],'DIABETES':[DIABETES],'COPD':[COPD],'ASTHMA':[ASTHMA],'INMSUPR':[INMSUPR],'HIPERTENSION':[HIPERTENSION],'OTHER_DISEASE':[OTHER_DISEASE],'CARDIOVASCULAR':[CARDIOVASCULAR],'OBESITY':[OBESITY],'RENAL_CHRONIC':[RENAL_CHRONIC],'TOBACCO':[TOBACCO],'CLASIFFICATION_FINAL':[CLASIFFICATION_FINAL],'ICU':[ICU]})
    df = df.replace(97, np.nan, regex=True)
    df = df.replace(98, np.nan, regex=True)
    df = df.replace(99, np.nan, regex=True)
    
    df['SEX'] = df['SEX'].replace(to_replace=['Female', 'Male'], value=[1, 2])
    df['PATIENT_TYPE'] = df['PATIENT_TYPE'].replace(to_replace=['Home', 'Hospital'], value=[1, 2])
    df['INTUBED'] = df['INTUBED'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['PNEUMONIA'] = df['PNEUMONIA'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['PREGNANT'] = df['PREGNANT'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['DIABETES'] = df['DIABETES'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['COPD'] = df['COPD'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['ASTHMA'] = df['ASTHMA'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['INMSUPR'] = df['INMSUPR'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['HIPERTENSION'] = df['HIPERTENSION'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['OTHER_DISEASE'] = df['OTHER_DISEASE'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['CARDIOVASCULAR'] = df['CARDIOVASCULAR'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['OBESITY'] = df['OBESITY'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['RENAL_CHRONIC'] = df['RENAL_CHRONIC'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['TOBACCO'] = df['TOBACCO'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['CLASIFFICATION_FINAL'] = df['CLASIFFICATION_FINAL'].replace(to_replace=['No', 'yes'], value=[2, 1])
    df['ICU'] = df['ICU'].replace(to_replace=['No', 'yes'], value=[2, 1])
    x = df
    x = np.asarray(x)
    prediction = model.predict(x.reshape(1, -1))
    if prediction==1:
        result='Dengan beberapa penyakit yang diidap pasien, kemungkinan besar pasien bisa meninggal dunia'
    elif prediction==0:
        result='Dengan beberapa penyakit yang diidap pasien, kemungkinan besar pasien masih dapat bertahan hidup'
    return result

# %%
outputs = gr.outputs.Textbox()
# result = ' '
# if outputs==1:
#     result='Diabetic'
# elif outputs==0:
#     result='Non-Diabetic'
app = gr.Interface(fn=died, inputs=['number','number','text','text','text','text','number','text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'text', 'number', 'text'], outputs=outputs,description="This is a diabetes model")
app.launch(share=True)
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\gradio\outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7861
# Running on public URL: https://4194826df72959abbc.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://4194826df72959abbc.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [raw]
# 'USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'

# %% [markdown]
# ## Confusion Matrix

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_test)

print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])

# %%
sns.set(font_scale=1.5)
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test))
